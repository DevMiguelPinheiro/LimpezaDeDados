# %%
import pandas as pd

# %%
tabela = pd.read_csv("Clientes.csv",sep = ";",encoding='latin1')
display(tabela)
# Out:
#       ClienteID    Origem  Idade Salário Anual (R$)  Nota (1-100)  \
# 0             1    Normal     19              15000            39
# 1             2    Normal     21              35000            81
# 2             3  Promoção     20              86000             2
# 3             4  Promoção     23              59000            73
# 4             5  Promoção     31              38000            48
# ...         ...       ...    ...                ...           ...
# 1995       1996  Promoção     71             184387            48
# 1996       1997  Promoção     91              73158            28
# 1997       1998    Normal     87              90961            14
# 1998       1999    Normal     77             182109             4
# 1999       2000    Normal     90             110610            64
#
#            Profissão  Experiência Trabalho  Tamanho Família Unnamed: 8
# 0              Saúde                     1                4        NaN
# ...

# %%
tabela.drop(columns=['Unnamed: 8'])
# Out:
#       ClienteID    Origem  Idade Salário Anual (R$)  Nota (1-100)  \
# 0             1    Normal     19              15000            39
# 1             2    Normal     21              35000            81
# 2             3  Promoção     20              86000             2
# 3             4  Promoção     23              59000            73
# 4             5  Promoção     31              38000            48
# ...         ...       ...    ...                ...           ...
# 1995       1996  Promoção     71             184387            48
# 1996       1997  Promoção     91              73158            28
# 1997       1998    Normal     87              90961            14
# 1998       1999    Normal     77             182109             4
# 1999       2000    Normal     90             110610            64
#
#            Profissão  Experiência Trabalho  Tamanho Família
# 0              Saúde                     1                4
# ...

# %% [markdown]
# Usar ascendin = false no sort_values para inverter a ordem padrão

# %%
tabela.sort_values(by ='Experiência Trabalho')
# Out:
#       ClienteID    Origem  Idade Salário Anual (R$)  Nota (1-100)  \
# 999        1000    Normal     97              66312            87
# 1183       1184  Promoção     62              73419            10
# 1176       1177    Normal     57              50429            35
# 1175       1176    Normal     61              52543            23
# 1172       1173  Promoção     82             184481            80
# ...         ...       ...    ...                ...           ...
# 566         567  Promoção     19             180331            22
# 473         474    Normal     20             130813           100
# 603         604  Promoção     91              69720            74
# 392         393    Normal     21             119116            42
# 405         406  Promoção     65             119889            19
#
#            Profissão  Experiência Trabalho  Tamanho Família Unnamed: 8
# 999   Entretenimento                     0                1        NaN
# ...

# %%
somaSalarioAnual = tabela['Salário Anual (R$)'].sum()
print(f'{somaSalarioAnual}')
# Out:
# ão ...

# %%
print(tabela.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ClienteID             2000 non-null   int64
#  1   Origem                2000 non-null   object
#  2   Idade                 2000 non-null   int64
#  3   Salário Anual (R$)    2000 non-null   object
#  4   Nota (1-100)          2000 non-null   int64
#  5   Profissão             1965 non-null   object
#  6   Experiência Trabalho  2000 non-null   int64
#  7   Tamanho Família       2000 non-null   int64
#  8   Unnamed: 8            1 non-null      object
# dtypes: int64(5), object(4)
# memory usage: 140.8+ KB
# None

# %% [markdown]
# coerce serve para dizer que os valores nulos vao ser substituidos po NAN

# %%
tabela["Salário Anual (R$)"] = pd.to_numeric(tabela["Salário Anual (R$)"],errors = "coerce")
print(tabela.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ClienteID             2000 non-null   int64
#  1   Origem                2000 non-null   object
#  2   Idade                 2000 non-null   int64
#  3   Salário Anual (R$)    1999 non-null   float64
#  4   Nota (1-100)          2000 non-null   int64
#  5   Profissão             1965 non-null   object
#  6   Experiência Trabalho  2000 non-null   int64
#  7   Tamanho Família       2000 non-null   int64
#  8   Unnamed: 8            1 non-null      object
# dtypes: float64(1), int64(5), object(3)
# memory usage: 140.8+ KB
# None

# %%
display(tabela[tabela["Profissão"].isna()])
# Out:
#       ClienteID    Origem  Idade  Salário Anual (R$)  Nota (1-100) Profissão  \
# 79           80  Promoção     49                 NaN            38       NaN
# 118         119  Promoção     51             84000.0            39       NaN
# 219         220  Promoção     59             76000.0            57       NaN
# 237         238    Normal     95             36000.0            35       NaN
# 437         438    Normal     76            136259.0            14       NaN
# 440         441  Promoção      0             57373.0             1       NaN
# 498         499    Normal     95            121725.0            10       NaN
# 545         546  Promoção     89            107359.0            29       NaN
# 601         602    Normal     61            126370.0            27       NaN
# 641         642    Normal     66            121377.0            19       NaN
# 665         666    Normal     28            101414.0            64       NaN
# ...

# %%
tabela = tabela.dropna()
print(tabela.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1 entries, 3 to 3
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ClienteID             1 non-null      int64
#  1   Origem                1 non-null      object
#  2   Idade                 1 non-null      int64
#  3   Salário Anual (R$)    1 non-null      float64
#  4   Nota (1-100)          1 non-null      int64
#  5   Profissão             1 non-null      object
#  6   Experiência Trabalho  1 non-null      int64
#  7   Tamanho Família       1 non-null      int64
#  8   Unnamed: 8            1 non-null      object
# dtypes: float64(1), int64(5), object(3)
# memory usage: 80.0+ bytes
# None

# %%
somaSalarioAnual = tabela['Salário Anual (R$)'].sum()
print(f'R$ {somaSalarioAnual}')
# Out:
# R$ 59000.0

# %%
#25,50,75%  organiza a tabela de acordo com a quantidade de itens naquela coluna
#std desvio padrao
display(tabela.describe())
# Out:
#        ClienteID  Idade  Salário Anual (R$)  Nota (1-100)  \
# count        1.0    1.0                 1.0           1.0
# mean         4.0   23.0             59000.0          73.0
# std          NaN    NaN                 NaN           NaN
# min          4.0   23.0             59000.0          73.0
# 25%          4.0   23.0             59000.0          73.0
# 50%          4.0   23.0             59000.0          73.0
# 75%          4.0   23.0             59000.0          73.0
# max          4.0   23.0             59000.0          73.0
#
#        Experiência Trabalho  Tamanho Família
# count                   1.0              1.0
# mean                    0.0              2.0
# std                     NaN              NaN
# min                     0.0              2.0
# 25%                     0.0              2.0
# 50%                     0.0              2.0
# 75%                     0.0              2.0
# max                     0.0              2.0

# %%
# !pip install plotly

# %%
import plotly.express as px
grafico  = px.histogram(tabela,x = "Salário Anual (R$)" , y = "Nota (1-100)")
grafico.show()

# %%
grafico  = px.histogram(tabela,x = "Salário Anual (R$)" , y = "Nota (1-100)",color ="Origem")
grafico.show()
