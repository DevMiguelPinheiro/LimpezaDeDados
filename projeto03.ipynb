# %%
import pandas as pd

# %%
base = pd.read_excel("ChavesClientes.xlsx",sheet_name ="base")
base.head()
# Out:
#    ID ChaveSituacao ClassRisco   CatCliente  Pagamento
# 0   1          32FC     Ccinza  Basic-Alpha          1
# 1   2          25MV   AAmarelo        Black          1
# 2   3          27MV  B-Amarelo   Basic-Beta          1
# 3   4          26FD   BAmarelo        Black          0
# 4   5          26FD  C-Amarelo        Black          0

# %%
base.groupby(["Pagamento","ChaveSituacao"])["Pagamento"].count()
# problema em chave situacao separar
# Out:
# Pagamento  ChaveSituacao
# 0          26FD             2
#            28FC             2
#            28MD             1
#            30FC             1
#            31MD             1
# 1          25FD             1
#            25FV             1
#            25MV             1
#            26MC             2
#            27MC             1
#            27MD             2
#            27MV             1
#            28FS             1
#            29MV             1
#            31MV             1
#            32FC             1
# Name: Pagamento, dtype: int64

# %%
texto = "32FC"
texto[-1]
# Out:
# 'C'

# %%
texto[2:]
# Out:
# 'FC'

# %%
texto[:2]
# Out:
# '32'

# %%
texto[2:3]
# Out:
# 'F'

# %%
texto[3:4]
# Out:
# 'C'

# %%
base['Idade'] =  base.ChaveSituacao.str[:2]# para adicionar uma coluna na tabela
base.head()
# Out:
#    ID ChaveSituacao ClassRisco   CatCliente  Pagamento Idade
# 0   1          32FC     Ccinza  Basic-Alpha          1    32
# 1   2          25MV   AAmarelo        Black          1    25
# 2   3          27MV  B-Amarelo   Basic-Beta          1    27
# 3   4          26FD   BAmarelo        Black          0    26
# 4   5          26FD  C-Amarelo        Black          0    26

# %%
base['Gênero'] =  base.ChaveSituacao.str[2:3]
base.head()
# Out:
#    ID ChaveSituacao ClassRisco   CatCliente  Pagamento Idade Gênero
# 0   1          32FC     Ccinza  Basic-Alpha          1    32      F
# 1   2          25MV   AAmarelo        Black          1    25      M
# 2   3          27MV  B-Amarelo   Basic-Beta          1    27      M
# 3   4          26FD   BAmarelo        Black          0    26      F
# 4   5          26FD  C-Amarelo        Black          0    26      F

# %%
base['Estado Civil'] =  base.ChaveSituacao.str[3:4]
base.head()
# Out:
#    ID ChaveSituacao ClassRisco   CatCliente  Pagamento Idade Gênero  \
# 0   1          32FC     Ccinza  Basic-Alpha          1    32      F
# 1   2          25MV   AAmarelo        Black          1    25      M
# 2   3          27MV  B-Amarelo   Basic-Beta          1    27      M
# 3   4          26FD   BAmarelo        Black          0    26      F
# 4   5          26FD  C-Amarelo        Black          0    26      F
#
#   Estado Civil
# 0            C
# 1            V
# 2            V
# 3            D
# 4            D

# %%
display(base)
# Out:
#     ID ChaveSituacao ClassRisco      CatCliente  Pagamento Idade Gênero  \
# 0    1          32FC     Ccinza     Basic-Alpha          1    32      F
# 1    2          25MV   AAmarelo           Black          1    25      M
# 2    3          27MV  B-Amarelo      Basic-Beta          1    27      M
# 3    4          26FD   BAmarelo           Black          0    26      F
# 4    5          26FD  C-Amarelo           Black          0    26      F
# 5    6          28FC  C-Amarelo  Platinum-Alpha          0    28      F
# 6    7          27MD    A-Verde   Platinum-Beta          1    27      M
# 7    8          31MD    C-Cinza           Basic          0    31      M
# 8    9          28FS    A-Cinza           Black          1    28      F
# 9   10          31MV  C+Amarelo        Platinum          1    31      M
# 10  11          29MV   AAmarelo           Basic          1    29      M
# 11  12          30FC    C-Cinza      Basic-Beta          0    30      F
# ...

# %%
somaMasculino = base[base['Gênero'] == 'M'].shape[0]
somaFeminino = base[base['Gênero'] == 'F'].shape[0]
print(somaMasculino)
print(somaFeminino)
# Out:
# 11
# 9

# %%
texto = 'basic-alpha'
texto.split('-')
# Out:
# ['basic', 'alpha']

# %%
base['Categoria'] = base.CatCliente.str.split('-').str.get(0)
base.head()
# Out:
#    ID ChaveSituacao ClassRisco   CatCliente  Pagamento Idade Gênero  \
# 0   1          32FC     Ccinza  Basic-Alpha          1    32      F
# 1   2          25MV   AAmarelo        Black          1    25      M
# 2   3          27MV  B-Amarelo   Basic-Beta          1    27      M
# 3   4          26FD   BAmarelo        Black          0    26      F
# 4   5          26FD  C-Amarelo        Black          0    26      F
#
#   Estado Civil Categoria
# 0            C     Basic
# 1            V     Black
# 2            V     Basic
# 3            D     Black
# 4            D     Black

# %%
base['CatVIP'] =  base.CatCliente.str.split('-').str.get(1)
base.head()
# Out:
#    ID ChaveSituacao ClassRisco   CatCliente  Pagamento Idade Gênero  \
# 0   1          32FC     Ccinza  Basic-Alpha          1    32      F
# 1   2          25MV   AAmarelo        Black          1    25      M
# 2   3          27MV  B-Amarelo   Basic-Beta          1    27      M
# 3   4          26FD   BAmarelo        Black          0    26      F
# 4   5          26FD  C-Amarelo        Black          0    26      F
#
#   Estado Civil Categoria CatVIP
# 0            C     Basic  Alpha
# 1            V     Black    NaN
# 2            V     Basic   Beta
# 3            D     Black    NaN
# 4            D     Black    NaN

# %%
import re

# %%
re.findall('IFAM','eu estudo no IFAM')
# Out:
# ['IFAM']

# %%
re.findall('IFA+M','eu estudo no IFAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAM')
# Out:
# ['IFAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAM']

# %%
re.findall('IFA*M','eu estudo no IFM')
# Out:
# ['IFM']

# %%
re.findall('[A-Z]','eu estudo no IFAM')
# Out:
# ['I', 'F', 'A', 'M']

# %%
re.findall('[a-z]','eu estudo no IFAM')
# Out:
# ['e', 'u', 'e', 's', 't', 'u', 'd', 'o', 'n', 'o']

# %%
re.findall('[A-Z]+\w','eu estudo no Ifam')
# Out:
# ['If']

# %%
re.findall('[A-Z]+\w{2}','eu estudo no Ifam')
# Out:
# ['Ifa']

# %%
re.findall('[A-Z]','B-Amarelo')
# Out:
# ['B', 'A']

# %%
re.findall('^[A-Z]','B-Amarelo')
# Out:
# ['B']

# %%
re.findall('^[A-Z].?','B-Amarelo')
# Out:
# ['B-']

# %%
re.findall('^[A-Z].?','AAmarelo')
# Out:
# ['AA']

# %%
re.findall('^[A-Z][^A-Z]?','B-Amarelo')
# Out:
# ['B-']

# %%
re.findall('^[A-Z][^A-Za-z]?','Croxo')
# Out:
# ['C']

# %%
base['Risco'] = base.ClassRisco.apply(lambda x:re.findall('^[A-Z][^A-Za-z]?',x)[0])
base.head()
# Out:
#    ID ChaveSituacao ClassRisco   CatCliente  Pagamento Idade Gênero  \
# 0   1          32FC     Ccinza  Basic-Alpha          1    32      F
# 1   2          25MV   AAmarelo        Black          1    25      M
# 2   3          27MV  B-Amarelo   Basic-Beta          1    27      M
# 3   4          26FD   BAmarelo        Black          0    26      F
# 4   5          26FD  C-Amarelo        Black          0    26      F
#
#   Estado Civil Categoria CatVIP Risco
# 0            C     Basic  Alpha     C
# 1            V     Black    NaN     A
# 2            V     Basic   Beta    B-
# 3            D     Black    NaN     B
# 4            D     Black    NaN    C-

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             20 non-null     int64
#  1   ChaveSituacao  20 non-null     object
#  2   ClassRisco     20 non-null     object
#  3   CatCliente     20 non-null     object
#  4   Pagamento      20 non-null     int64
#  5   Idade          20 non-null     object
#  6   Gênero         20 non-null     object
#  7   Estado Civil   20 non-null     object
#  8   Categoria      20 non-null     object
#  9   CatVIP         8 non-null      object
#  10  Risco          20 non-null     object
# dtypes: int64(2), object(9)
# memory usage: 1.8+ KB

# %%
base["Idade"] = pd.to_numeric(base["Idade"],errors = "coerce")

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             20 non-null     int64
#  1   ChaveSituacao  20 non-null     object
#  2   ClassRisco     20 non-null     object
#  3   CatCliente     20 non-null     object
#  4   Pagamento      20 non-null     int64
#  5   Idade          20 non-null     int64
#  6   Gênero         20 non-null     object
#  7   Estado Civil   20 non-null     object
#  8   Categoria      20 non-null     object
#  9   CatVIP         8 non-null      object
#  10  Risco          20 non-null     object
# dtypes: int64(3), object(8)
# memory usage: 1.8+ KB

# %%
base.loc[base.CatVIP.isnull()]
# Out:
#     ID ChaveSituacao ClassRisco CatCliente  Pagamento  Idade Gênero  \
# 1    2          25MV   AAmarelo      Black          1     25      M
# 3    4          26FD   BAmarelo      Black          0     26      F
# 4    5          26FD  C-Amarelo      Black          0     26      F
# 7    8          31MD    C-Cinza      Basic          0     31      M
# 8    9          28FS    A-Cinza      Black          1     28      F
# 9   10          31MV  C+Amarelo   Platinum          1     31      M
# 10  11          29MV   AAmarelo      Basic          1     29      M
# 12  13          28FC     Bverde      Basic          0     28      F
# 13  14          26MC    A-Verde   Platinum          1     26      M
# 15  16          27MC     B-Roxo   Platinum          1     27      M
# 16  17          25FD    A-Verde      Black          1     25      F
# 19  20          25FV   AAmarelo   Platinum          1     25      F
#
#    Estado Civil Categoria CatVIP Risco
# 1             V     Black    NaN     A
# ...

# %%
base.loc[base.CatVIP.isnull(),"CatVIP"] = "Comum"
base.head()
# Out:
#    ID ChaveSituacao ClassRisco   CatCliente  Pagamento  Idade Gênero  \
# 0   1          32FC     Ccinza  Basic-Alpha          1     32      F
# 1   2          25MV   AAmarelo        Black          1     25      M
# 2   3          27MV  B-Amarelo   Basic-Beta          1     27      M
# 3   4          26FD   BAmarelo        Black          0     26      F
# 4   5          26FD  C-Amarelo        Black          0     26      F
#
#   Estado Civil Categoria CatVIP Risco
# 0            C     Basic  Alpha     C
# 1            V     Black  Comum     A
# 2            V     Basic   Beta    B-
# 3            D     Black  Comum     B
# 4            D     Black  Comum    C-

# %%
base.loc[base.CatVIP.isnull()]
# Out:
# Empty DataFrame
# Columns: [ID, ChaveSituacao, ClassRisco, CatCliente, Pagamento, Idade, Gênero, Estado Civil, Categoria, CatVIP, Risco]
# Index: []

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             20 non-null     int64
#  1   ChaveSituacao  20 non-null     object
#  2   ClassRisco     20 non-null     object
#  3   CatCliente     20 non-null     object
#  4   Pagamento      20 non-null     int64
#  5   Idade          20 non-null     int64
#  6   Gênero         20 non-null     object
#  7   Estado Civil   20 non-null     object
#  8   Categoria      20 non-null     object
#  9   CatVIP         20 non-null     object
#  10  Risco          20 non-null     object
# dtypes: int64(3), object(8)
# memory usage: 1.8+ KB

# %%
display(base)
# Out:
#     ID ChaveSituacao ClassRisco      CatCliente  Pagamento  Idade Gênero  \
# 0    1          32FC     Ccinza     Basic-Alpha          1     32      F
# 1    2          25MV   AAmarelo           Black          1     25      M
# 2    3          27MV  B-Amarelo      Basic-Beta          1     27      M
# 3    4          26FD   BAmarelo           Black          0     26      F
# 4    5          26FD  C-Amarelo           Black          0     26      F
# 5    6          28FC  C-Amarelo  Platinum-Alpha          0     28      F
# 6    7          27MD    A-Verde   Platinum-Beta          1     27      M
# 7    8          31MD    C-Cinza           Basic          0     31      M
# 8    9          28FS    A-Cinza           Black          1     28      F
# 9   10          31MV  C+Amarelo        Platinum          1     31      M
# 10  11          29MV   AAmarelo           Basic          1     29      M
# 11  12          30FC    C-Cinza      Basic-Beta          0     30      F
# ...

# %%
base.groupby(["Pagamento","CatVIP"])["Pagamento"].count()
# Out:
# Pagamento  CatVIP
# 0          Alpha     1
#            Beta      2
#            Comum     4
# 1          Alpha     3
#            Beta      2
#            Comum     8
# Name: Pagamento, dtype: int64

# %%
base.to_csv('meu_arquivo_tratado.csv', index=False)
